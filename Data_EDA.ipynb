# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

#data source https://data.cityofnewyork.us/Public-Safety/NYC-crime/qb7u-rbmr

# %%
df1 = pd.read_csv('/content/drive/MyDrive/NYPD_Complaint_Data_Historic.csv').drop(['CMPLNT_TO_DT','CMPLNT_NUM','CMPLNT_TO_TM','CRM_ATPT_CPTD_CD','SUSP_SEX','TRANSIT_DISTRICT','STATION_NAME','VIC_AGE_GROUP','VIC_RACE','VIC_SEX','ADDR_PCT_CD','RPT_DT','HADEVELOPT','HOUSING_PSA','JURISDICTION_CODE','CMPLNT_FR_TM','SUSP_AGE_GROUP','SUSP_RACE','PARKS_NM'],axis=1)

# %%
df1
# Out:
#         CMPLNT_FR_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0         03/29/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 1         02/06/2018    341                   PETIT LARCENY  333.0
# 2         11/21/2018    341                   PETIT LARCENY  321.0
# 3         06/09/2018    361   OFF. AGNST PUB ORD SENSBLTY &  639.0
# 4         11/10/2018    341                   PETIT LARCENY  333.0
# ...              ...    ...                             ...    ...
# 7825494   05/01/2008    235                 DANGEROUS DRUGS  511.0
# 7825495   05/18/2018    344    ASSAULT 3 & RELATED OFFENSES  101.0
# 7825496   11/19/2018    109                   GRAND LARCENY  421.0
# 7825497   02/03/2018    578                   HARRASSMENT 2  638.0
# 7825498   01/05/2018    233                      SEX CRIMES  175.0
#
#                                        PD_DESC   LAW_CAT_CD        BORO_NM  \
# 0               MISCHIEF, CRIMINAL 4, OF MOTOR  MISDEMEANOR      MANHATTAN
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7825499 entries, 0 to 7825498
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   CMPLNT_FR_DT       object
#  1   KY_CD              int64
#  2   OFNS_DESC          object
#  3   PD_CD              float64
#  4   PD_DESC            object
#  5   LAW_CAT_CD         object
#  6   BORO_NM            object
#  7   LOC_OF_OCCUR_DESC  object
#  8   PREM_TYP_DESC      object
#  9   JURIS_DESC         object
#  10  X_COORD_CD         object
#  11  Y_COORD_CD         object
#  12  Latitude           float64
#  13  Longitude          float64
#  14  Lat_Lon            object
#  15  PATROL_BORO        object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 955.3+ MB

# %%
df1.isna().sum()
# Out:
# CMPLNT_FR_DT             655
# KY_CD                      0
# OFNS_DESC              18832
# PD_CD                   6761
# PD_DESC                 6761
# LAW_CAT_CD                 0
# BORO_NM                12480
# LOC_OF_OCCUR_DESC    1618063
# PREM_TYP_DESC          42015
# JURIS_DESC                 0
# X_COORD_CD             17339
# Y_COORD_CD             17339
# Latitude               17339
# Longitude              17339
# Lat_Lon                17339
# PATROL_BORO             7218
# dtype: int64

# %%
df1.describe()
# Out:
#               KY_CD         PD_CD      Latitude     Longitude
# count  7.825499e+06  7.818738e+06  7.808160e+06  7.808160e+06
# mean   2.968756e+02  4.126822e+02  4.073517e+01 -7.392551e+01
# std    1.511127e+02  2.176568e+02  8.609054e-02  7.825796e-02
# min    1.010000e+02  1.000000e+02  4.011271e+01 -7.751921e+01
# 25%    1.170000e+02  2.540000e+02  4.067280e+01 -7.397287e+01
# 50%    3.410000e+02  3.800000e+02  4.073236e+01 -7.392721e+01
# 75%    3.510000e+02  6.370000e+02  4.081215e+01 -7.388291e+01
# max    8.810000e+02  9.750000e+02  5.965727e+01 -7.368479e+01

# %%
df1=df1.drop_duplicates()

# %%
df1.isna().sum()
# Out:
# CMPLNT_FR_DT             655
# KY_CD                      0
# OFNS_DESC              18386
# PD_CD                   6474
# PD_DESC                 6474
# LAW_CAT_CD                 0
# BORO_NM                12089
# LOC_OF_OCCUR_DESC    1575036
# PREM_TYP_DESC          41089
# JURIS_DESC                 0
# X_COORD_CD             12995
# Y_COORD_CD             12995
# Latitude               12995
# Longitude              12995
# Lat_Lon                12995
# PATROL_BORO             6899
# dtype: int64

# %%
df1=df1.drop(['LOC_OF_OCCUR_DESC'],axis=1)

# %%
df1
# Out:
#         CMPLNT_FR_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0         03/29/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 2         11/21/2018    341                   PETIT LARCENY  321.0
# 5         03/12/2018    113                         FORGERY  729.0
# 6         04/07/2013    118               DANGEROUS WEAPONS  793.0
# 7         09/12/2018    121  CRIMINAL MISCHIEF & RELATED OF  269.0
# ...              ...    ...                             ...    ...
# 7825494   05/01/2008    235                 DANGEROUS DRUGS  511.0
# 7825495   05/18/2018    344    ASSAULT 3 & RELATED OFFENSES  101.0
# 7825496   11/19/2018    109                   GRAND LARCENY  421.0
# 7825497   02/03/2018    578                   HARRASSMENT 2  638.0
# 7825498   01/05/2018    233                      SEX CRIMES  175.0
#
#                                        PD_DESC   LAW_CAT_CD        BORO_NM  \
# 0               MISCHIEF, CRIMINAL 4, OF MOTOR  MISDEMEANOR      MANHATTAN
# ...

# %%
df1=df1.dropna()

# %%
df3=df1.dropna()

# %%
df2 = df1[~(df1['PATROL_BORO'] == "PATROL BORO MAN NORTH")].index 
df4 = df3[~(df3['PATROL_BORO'] == "PATROL BORO MAN SOUTH")].index 

df1.drop(df2, inplace = True)
df3.drop(df4, inplace = True)
df1.append(df3, ignore_index=True)
# Out:
#        CMPLNT_FR_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0        03/29/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 1        03/12/2018    113                         FORGERY  729.0
# 2        09/26/2018    106                  FELONY ASSAULT  109.0
# 3        03/26/2018    351  CRIMINAL MISCHIEF & RELATED OF  258.0
# 4        10/10/2018    341                   PETIT LARCENY  343.0
# ...             ...    ...                             ...    ...
# 782196   11/12/2018    109                   GRAND LARCENY  404.0
# 782197   07/15/2018    344    ASSAULT 3 & RELATED OFFENSES  113.0
# 782198   04/24/2018    341                   PETIT LARCENY  321.0
# 782199   06/26/2018    341                   PETIT LARCENY  343.0
# 782200   05/01/2008    235                 DANGEROUS DRUGS  511.0
#
#                                                   PD_DESC   LAW_CAT_CD  \
# 0                          MISCHIEF, CRIMINAL 4, OF MOTOR  MISDEMEANOR
# ...

# %%
df1
# Out:
#         CMPLNT_FR_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0         03/29/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 5         03/12/2018    113                         FORGERY  729.0
# 10        09/26/2018    106                  FELONY ASSAULT  109.0
# 20        03/26/2018    351  CRIMINAL MISCHIEF & RELATED OF  258.0
# 36        10/10/2018    341                   PETIT LARCENY  343.0
# ...              ...    ...                             ...    ...
# 7825341   05/26/2018    351  CRIMINAL MISCHIEF & RELATED OF  259.0
# 7825368   02/26/2018    344    ASSAULT 3 & RELATED OFFENSES  101.0
# 7825399   06/04/2018    351  CRIMINAL MISCHIEF & RELATED OF  258.0
# 7825486   04/24/2018    235                 DANGEROUS DRUGS  567.0
# 7825491   01/31/2018    344    ASSAULT 3 & RELATED OFFENSES  101.0
#
#                                   PD_DESC   LAW_CAT_CD    BORO_NM  \
# 0          MISCHIEF, CRIMINAL 4, OF MOTOR  MISDEMEANOR  MANHATTAN
# ...

# %%
df2 = df1[~(df1['PATROL_BORO'] == "PATROL BORO MAN NORTH")].index 
df1.drop(df2, inplace = True)
df1.head()
# Out:
#    CMPLNT_FR_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0    03/29/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 5    03/12/2018    113                         FORGERY  729.0
# 10   09/26/2018    106                  FELONY ASSAULT  109.0
# 20   03/26/2018    351  CRIMINAL MISCHIEF & RELATED OF  258.0
# 36   10/10/2018    341                   PETIT LARCENY  343.0
#
#                            PD_DESC   LAW_CAT_CD    BORO_NM  \
# 0   MISCHIEF, CRIMINAL 4, OF MOTOR  MISDEMEANOR  MANHATTAN
# 5   FORGERY,ETC.,UNCLASSIFIED-FELO       FELONY  MANHATTAN
# 10        ASSAULT 2,1,UNCLASSIFIED       FELONY  MANHATTAN
# 20  CRIMINAL MISCHIEF 4TH, GRAFFIT  MISDEMEANOR  MANHATTAN
# 36        LARCENY,PETIT OF BICYCLE  MISDEMEANOR  MANHATTAN
#
#                   PREM_TYP_DESC           JURIS_DESC X_COORD_CD Y_COORD_CD  \
# 0   PARKING LOT/GARAGE (PUBLIC)     N.Y. POLICE DEPT  1,000,565    234,704
# 5          TRANSIT - NYC SUBWAY  N.Y. TRANSIT POLICE  1,001,575    232,339
# ...

# %%
df4 = df3[~(df3['PATROL_BORO'] == "PATROL BORO MAN SOUTH")].index 
df3.drop(df4, inplace = True)
df3.head()
# Out:
#     CMPLNT_FR_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 14    12/01/2018    359  OFFENSES AGAINST PUBLIC ADMINI  759.0
# 98    02/25/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 116   02/27/2018    109                   GRAND LARCENY  406.0
# 119   05/18/2018    578                   HARRASSMENT 2  637.0
# 152   02/25/2018    233                      SEX CRIMES  175.0
#
#                                      PD_DESC   LAW_CAT_CD    BORO_NM  \
# 14            PUBLIC ADMINISTATION,UNCLASS M  MISDEMEANOR  MANHATTAN
# 98            MISCHIEF, CRIMINAL 4, OF MOTOR  MISDEMEANOR  MANHATTAN
# 116  LARCENY,GRAND FROM PERSON, BAG OPEN/DIP       FELONY  MANHATTAN
# 119               HARASSMENT,SUBD 1,CIVILIAN    VIOLATION  MANHATTAN
# 152                         SEXUAL ABUSE 3,2  MISDEMEANOR  MANHATTAN
#
#                   PREM_TYP_DESC           JURIS_DESC X_COORD_CD Y_COORD_CD  \
# 14                       STREET     N.Y. POLICE DEPT    990,112    209,137
# ...

# %%
df1=df1.drop(['PATROL_BORO','PD_DESC','BORO_NM','LAW_CAT_CD','JURIS_DESC'],axis=1)

# %%
df3=df3.drop(['PATROL_BORO','PD_DESC','BORO_NM','LAW_CAT_CD','JURIS_DESC'],axis=1)

# %%
df1
# Out:
#         CMPLNT_FR_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0         03/29/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 5         03/12/2018    113                         FORGERY  729.0
# 10        09/26/2018    106                  FELONY ASSAULT  109.0
# 20        03/26/2018    351  CRIMINAL MISCHIEF & RELATED OF  258.0
# 36        10/10/2018    341                   PETIT LARCENY  343.0
# ...              ...    ...                             ...    ...
# 7825341   05/26/2018    351  CRIMINAL MISCHIEF & RELATED OF  259.0
# 7825368   02/26/2018    344    ASSAULT 3 & RELATED OFFENSES  101.0
# 7825399   06/04/2018    351  CRIMINAL MISCHIEF & RELATED OF  258.0
# 7825486   04/24/2018    235                 DANGEROUS DRUGS  567.0
# 7825491   01/31/2018    344    ASSAULT 3 & RELATED OFFENSES  101.0
#
#                        PREM_TYP_DESC X_COORD_CD Y_COORD_CD   Latitude  \
# 0        PARKING LOT/GARAGE (PUBLIC)  1,000,565    234,704  40.810877
# ...

# %%
df3
# Out:
#         CMPLNT_FR_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 14        12/01/2018    359  OFFENSES AGAINST PUBLIC ADMINI  759.0
# 98        02/25/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 116       02/27/2018    109                   GRAND LARCENY  406.0
# 119       05/18/2018    578                   HARRASSMENT 2  637.0
# 152       02/25/2018    233                      SEX CRIMES  175.0
# ...              ...    ...                             ...    ...
# 7825370   11/12/2018    109                   GRAND LARCENY  404.0
# 7825411   07/15/2018    344    ASSAULT 3 & RELATED OFFENSES  113.0
# 7825432   04/24/2018    341                   PETIT LARCENY  321.0
# 7825488   06/26/2018    341                   PETIT LARCENY  343.0
# 7825494   05/01/2008    235                 DANGEROUS DRUGS  511.0
#
#                       PREM_TYP_DESC X_COORD_CD Y_COORD_CD   Latitude  \
# 14                           STREET    990,112    209,137  40.740716
# ...

# %%
pd.concat([df1, df3], ignore_index=True).to_csv('NewYorkDataSetFinal.csv')
